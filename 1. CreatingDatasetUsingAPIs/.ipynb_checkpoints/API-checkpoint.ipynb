# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=10"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYmY0ZWI5NjNlY2YwZTVhNmY1MTkzZGMzNmJlOWViNiIsIm5iZiI6MTc1Njc5MzUxNC45MDMsInN1YiI6IjY4YjY4YWFhM2RhOTljNjY1ZTFmMmRjNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._wxYgDVH1dXoZtg4Z1PU8w-hll_GXfeS1ZWC_uHP95g"
}

response = requests.get(url, headers=headers).json()

response
# Out:
# {'page': 10,
#  'results': [{'adult': False,
#    'backdrop_path': '/9A0wQG38VdEu3DYh8HzXKXKhA6g.jpg',
#    'genre_ids': [12, 35, 10751],
#    'id': 1287536,
#    'original_language': 'en',
#    'original_title': 'Dora and the Search for Sol Dorado',
#    'overview': 'Dora, Diego, and their new friends trek through the perilous dangers of the Amazonian jungle in search of the ancient and powerful treasure of Sol Dorado to keep it out of enemy hands.',
#    'popularity': 23.632,
#    'poster_path': '/r3d6u2n7iPoWNsSWwlJJWrDblOH.jpg',
#    'release_date': '2025-07-02',
#    'title': 'Dora and the Search for Sol Dorado',
#    'video': False,
#    'vote_average': 6.6,
#    'vote_count': 87},
#   {'adult': False,
#    'backdrop_path': '/htuuuEwAvDVECMpb0ltLLyZyDDt.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
# ...

# %%
for i in response['results']:
    print(i['title'],i['vote_average'])
# Out:
# Dora and the Search for Sol Dorado 6.6
# The Godfather 8.686
# Toy Story 7.97
# Titanic 7.906
# My Fault: London 7.474
# Fight Club 8.437
# Hook 5.8
# El beso de Judas 10.0
# Twilight 6.287
# Avatar: The Way of Water 7.613
# The Lord of the Rings: The Fellowship of the Ring 8.424
# Provocation 5.475
# Yours, Mine & Ours 6.2
# Sugar Mill 7.932
# Thandakaaranyam 0.0
# Eddington 6.451
# Fifty Shades Freed 6.688
# Gladiator II 6.67
# Fifty Shades of Grey 5.88
# Jaws 7.676

# %%
#example of populating dataframe
d={'name':['Rohan','Mohan'],'Age':[20,21]}
df = pd.DataFrame(d)
df
# Out:
#     name  Age
# 0  Rohan   20
# 1  Mohan   21

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])

d={'title':title, 'overview':overview, 'original_language':original_language, 'release_date':release_date, 'popularity':popularity, 'vote_count':vote_count, 'vote_average':vote_average}

df=pd.DataFrame(d)
df
# Out:
#                                                 title  \
# 0                  Dora and the Search for Sol Dorado
# 1                                       The Godfather
# 2                                           Toy Story
# 3                                             Titanic
# 4                                    My Fault: London
# 5                                          Fight Club
# 6                                                Hook
# 7                                    El beso de Judas
# 8                                            Twilight
# 9                            Avatar: The Way of Water
# 10  The Lord of the Rings: The Fellowship of the Ring
# 11                                        Provocation
# 12                                 Yours, Mine & Ours
# 13                                         Sugar Mill
# 14                                    Thandakaaranyam
# 15                                          Eddington
# ...

# %%
final = pd.DataFrame()

for j in range(1, 501):
    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page={}".format(j)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxYmY0ZWI5NjNlY2YwZTVhNmY1MTkzZGMzNmJlOWViNiIsIm5iZiI6MTc1Njc5MzUxNC45MDMsInN1YiI6IjY4YjY4YWFhM2RhOTljNjY1ZTFmMmRjNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ._wxYgDVH1dXoZtg4Z1PU8w-hll_GXfeS1ZWC_uHP95g"
    }
    
    response = requests.get(url, headers=headers).json()

    # Extract lists
    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average = []
    overview = []
    release_date = []
    
    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])
        release_date.append(i['release_date'])
    
    d = {
        'title': title, 
        'overview': overview, 
        'original_language': original_language, 
        'release_date': release_date, 
        'popularity': popularity, 
        'vote_count': vote_count, 
        'vote_average': vote_average
    }
    
    df = pd.DataFrame(d)
    
    # Use concat instead of append
    final = pd.concat([final, df], ignore_index=True)

# %%
final.to_csv('movies.csv')
